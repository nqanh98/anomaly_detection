# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
import display
import dataloader
from dataloader import ThermalData
import clustering
import anomaly_detection

# %% [markdown]
# 画像データの取得

# %%
thermal_img_files = dataloader.get_img_files(dir_path="./images/modules",gray=False)
thermal_img_files_gray = dataloader.get_img_files(dir_path="./images/modules",gray=True)

# %%
type(thermal_img_files), len(thermal_img_files)
# Out:
# (dict, 158)

# %% [markdown]
# 温度データの取得

# %%
data = ThermalData(thermal_img_files)

# %% [markdown]
# 温度分布の確認（個別）

# %% [markdown]
# 温度分布の確認

# %%
display.display_distributions(data.all_temperature, 
                              filepath = "hist_all_temperature.jpg")

# %%
display.display_distributions(data.scaled_all_temperature,
                              filepath = "hist_scaled_all_temperature.jpg")

# %% [markdown]
# クラスタ分類モデルの作成

# %%
gmm = anomaly_detection.AnoGMM(data.all_temperature)

# %%
gmm.display()

# %% [markdown]
# 個別画像の分析

# %%
input_file = "72.jpg"
#input_file = "12.jpg"
#input_file = "126.jpg"
#input_file = "130.jpg"

# %% [markdown]
# ピクセルのクラスタリング（by 温度＆位置）

# %%
clusters = clustering.TemperatureClusters(data.scaled_temperature_with_index[input_file], n_clusters=8)

# %%
clusters_temperature = clusters.get_clusters_data(data.temperature[input_file])
centers_temperature = np.stack([np.uint8(t.mean(axis=0)) for t in clusters_temperature])

# %% [markdown]
# クラスタリング結果の表示

# %%
img_clustered = centers_temperature[clusters.labels]
img_clustered = img_clustered.reshape(thermal_img_files[input_file].shape)

# %%
import matplotlib.cm as cm
from sklearn import preprocessing
mscaler = preprocessing.MinMaxScaler()
colors = cm.viridis(clusters.labels)[:, :3]
img_colored = np.uint8(mscaler.fit_transform(colors) * 255)
img_colored = img_colored.reshape(thermal_img_files[input_file].shape)
img_colored  = cv2.cvtColor(img_colored, cv2.COLOR_BGR2GRAY)

# %%
mask = data.scaled_temperature[input_file] > -2
mask = mask.reshape(thermal_img_files[input_file].shape)

# %%
display.display_modules({
    "Original": thermal_img_files[input_file], 
    "Gray": thermal_img_files_gray[input_file],
    "Masked": (thermal_img_files[input_file]*~mask),
    "Clustered": img_clustered,
    "Colored": img_colored,
})

# %%
display.display_distributions(data.scaled_temperature[input_file], 
                              filepath = "test.jpg", cluster_centers = clusters.centers[:, :3])

# %% [markdown]
# クラスタの分類&異常タイプの特定

# %%
display.display_distributions(data.all_temperature, 
                              filepath = "test.jpg", cluster_centers = centers_temperature, gmm=gmm)

# %%
predicted_classes = gmm.predict(centers_temperature)
cluster_types = [ gmm.index2class[c] for c in predicted_classes ]
weights = np.array([ gmm.index2class[c] =="High" for c in predicted_classes[clusters.labels] ])    
module_type = anomaly_detection.detect_module_type(cluster_types, weights)

# %%
print("predicted_classses:",predicted_classes)
print("cluster_types:",cluster_types)
print("Hotspot weight:", weights.mean())
print("Module type:", module_type)
# Out:
# predicted_classses: [2 3 0 1 1 1 1 1]
# cluster_types: ['High', 'Exception', 'Low', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium']
# Hotspot weight: 0.07211538461538461
# Module type: Single-Hotspot

# %% [markdown]
# 異常タイプの確認テスト

# %%
#for k in list(data.temperature.keys())[1:10]:
for k in list(data.temperature.keys()):    
    # -- kmeans ---
    clusters = clustering.TemperatureClusters(data.scaled_temperature_with_index[k], n_clusters=8)
    clusters_temperature = clusters.get_clusters_data(data.temperature[k])
    centers_temperature = np.stack([np.uint8(t.mean(axis=0)) for t in clusters_temperature])
    # -- gmm -- 
    predicted_classes = gmm.predict(centers_temperature)
    cluster_types = [ gmm.index2class[c] for c in predicted_classes ]
    # -- anomaly type --
    weights = np.array([ gmm.index2class[c] =="High" for c in predicted_classes[clusters.labels] ])
    module_type = anomaly_detection.detect_module_type(cluster_types, weights)
    print(k, module_type)
    print("Cluster types:",cluster_types)
    print("Hotspot weights:",weights.mean())
    # -- display -- 
    img_clustered = centers_temperature[clusters.labels] 
    img_hotspots = img_clustered * weights.reshape(-1,1)
    img_clustered = img_clustered.reshape(thermal_img_files[k].shape)
    img_hotspots = img_hotspots.reshape(thermal_img_files[k].shape)
    display.display_modules({
        "Original": thermal_img_files[k], 
        "Gray": thermal_img_files_gray[k],
        "Clustered": img_clustered,
        "Hotspots": img_hotspots,
    })
    display.display_distributions(
        data.all_temperature, 
        filepath = "./hist/hist_" + k,
        cluster_centers = centers_temperature,
        gmm = gmm
    )
# Out:
# 63.jpg Normal
# Cluster types: ['Low', 'Exception', 'Medium', 'Low', 'Medium', 'Medium', 'Medium', 'Low']
# Hotspot weights: 0.0
# 189.jpg Cluster-Hotspots
# Cluster types: ['High', 'Exception', 'High', 'High', 'Medium', 'High', 'High', 'Medium']
# Hotspot weights: 0.8571428571428571
# 77.jpg Normal
# Cluster types: ['Low', 'Low', 'Exception', 'Low', 'Low', 'Low', 'Exception', 'Low']
# Hotspot weights: 0.0
# 162.jpg Single-Hotspot
# Cluster types: ['High', 'Low', 'Exception', 'Low', 'Exception', 'Low', 'Medium', 'Medium']
# Hotspot weights: 0.15953947368421054
# 176.jpg Cluster-Hotspots
# Cluster types: ['High', 'Exception', 'High', 'Exception', 'Low', 'Low', 'High', 'High']
# Hotspot weights: 0.7770833333333333
# 88.jpg Normal
# Cluster types: ['Exception', 'Exception', 'Medium', 'Exception', 'Low', 'Low', 'Low', 'Exception']
# Hotspot weights: 0.0
# 200.jpg Cluster-Hotspots
# Cluster types: ['High', 'Exception', 'High', 'High', 'High', 'High', 'High', 'Medium']
# Hotspot weights: 0.8861607142857143
# 201.jpg Cluster-Hotspots
# Cluster types: ['High', 'Exception', 'High', 'High', 'High', 'Medium', 'High', 'High']
# Hotspot weights: 0.8772321428571429
# 188.jpg Cluster-Hotspots
# Cluster types: ['High', 'Exception', 'High', 'Exception', 'High', 'Low', 'High', 'High']
# Hotspot weights: 0.8917050691244239
# 76.jpg Normal
# Cluster types: ['Low', 'Exception', 'Low', 'Low', 'Exception', 'Low', 'Exception', 'Exception']
# Hotspot weights: 0.0
# 62.jpg Normal
# Cluster types: ['Low', 'Exception', 'Low', 'Low', 'Low', 'Medium', 'Low', 'Medium']
# Hotspot weights: 0.0
# 74.jpg Normal
# Cluster types: ['Exception', 'Exception', 'Low', 'Exception', 'Low', 'Exception', 'Exception', 'Exception']
# Hotspot weights: 0.0
# 60.jpg Normal
# Cluster types: ['Low', 'Low', 'Exception', 'Low', 'Low', 'Low', 'Low', 'Low']
# Hotspot weights: 0.0
# 48.jpg Normal
# Cluster types: ['Medium', 'Exception', 'Low', 'Low', 'Medium', 'Low', 'Low', 'Medium']
# Hotspot weights: 0.0
# 149.jpg Cluster-Hotspots
# Cluster types: ['High', 'High', 'Medium', 'Exception', 'Medium', 'High', 'High', 'Medium']
# Hotspot weights: 0.6129629629629629
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~/.pyenv/versions/anaconda3-2020.11/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-76d208b12cf8> in <module>
#      25         "Hotspots": img_hotspots,
#      26     })
# ---> 27     display.display_distributions(
#      28         data.all_temperature,
#      29         filepath = "hist_on_all_"+k,
#
# ~/afterFIT/work/rule_based_anomaly_detection/display.py in display_distributions(data, filepath, show, cluster_centers, gmm)
#      58     # -- distributions --
#      59     for i in range(data.shape[1]):
# ---> 60         ax1.hist(data[:,i], bins = 100, alpha = 0.5)
#      61     # -- mean and std --
#      62     ax1.axvline(x = data.mean(),
#
# ~/.pyenv/versions/anaconda3-2020.11/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.pyenv/versions/anaconda3-2020.11/lib/python3.8/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6721                 else:
#    6722                     height = m
# -> 6723                 bars = _barfunc(bins[:-1]+boffset, height, width,
#    6724                                 align='center', log=log,
#    6725                                 color=c, **{bottom_kwarg: bottom})
#
# ~/.pyenv/versions/anaconda3-2020.11/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.pyenv/versions/anaconda3-2020.11/lib/python3.8/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2479         args = zip(left, bottom, width, height, color, edgecolor, linewidth)
#    2480         for l, b, w, h, c, e, lw in args:
# -> 2481             r = mpatches.Rectangle(
#    2482                 xy=(l, b), width=w, height=h,
#    2483                 facecolor=c,
#
# ~/.pyenv/versions/anaconda3-2020.11/lib/python3.8/site-packages/matplotlib/patches.py in __init__(self, xy, width, height, angle, **kwargs)
#     740         """
#     741
# --> 742         Patch.__init__(self, **kwargs)
#     743
#     744         self._x0 = xy[0]
#
# ~/.pyenv/versions/anaconda3-2020.11/lib/python3.8/site-packages/matplotlib/patches.py in __init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      93
#      94         if len(kwargs):
# ---> 95             self.update(kwargs)
#      96
#      97     def get_verts(self):
#
# ~/.pyenv/versions/anaconda3-2020.11/lib/python3.8/site-packages/matplotlib/artist.py in update(self, props)
#     996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
# --> 998                     ret.append(func(v))
#     999         if ret:
#    1000             self.pchanged()
#
# ~/.pyenv/versions/anaconda3-2020.11/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# KeyboardInterrupt:

# %%
#ToDo
## 異常部分へのマーキング（赤で囲む）
